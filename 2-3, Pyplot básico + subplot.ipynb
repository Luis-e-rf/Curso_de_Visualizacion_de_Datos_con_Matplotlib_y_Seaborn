# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y,"rx")
plt.show()

# %%
plt.plot(x,y,"rs-")
plt.show()

# %%
plt.plot(x,y,"yD:")
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x)
plt.show()

# %%
fig, ax = plt.subplots()

# %%
fig

# %%
ax
# Out:
# <Axes: >

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"r--")
plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"r--")
plt.plot(y,x,"b:")
plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x,y,"r--")
plt.plot(y,x,"b:")
plt.subplot(2,1,2)
plt.pie(y)
plt.show()
